# %% [markdown]
# Analyze each csv
#
# look at column value types and null values

# %%
import polars as pl
import pandas as pd

# %% [markdown]
# Polars vs Pandas for loading data

# %%
direct_rentals = pl.read_csv("../data/direct_pickup_bike_rentals.csv")
registered_rentals = pl.read_csv("../data/registered_bike_rentals.csv")

print(direct_rentals.head())
print(direct_rentals.describe())
# Out:
# shape: (5, 4)
# ┌─────┬─────────────────────┬─────────┬─────────────┐
# │ id  ┆ datetime            ┆ user_id ┆ location_id │
# │ --- ┆ ---                 ┆ ---     ┆ ---         │
# │ i64 ┆ str                 ┆ i64     ┆ i64         │
# ╞═════╪═════════════════════╪═════════╪═════════════╡
# │ 1   ┆ 2011-01-01 00:24:04 ┆ 232     ┆ 2           │
# │ 2   ┆ 2011-01-01 00:30:19 ┆ 54      ┆ 14          │
# │ 3   ┆ 2011-01-01 00:39:08 ┆ 201     ┆ 5           │
# │ 4   ┆ 2011-01-01 01:01:12 ┆ 298     ┆ 13          │
# │ 5   ┆ 2011-01-01 01:02:37 ┆ 23      ┆ 14          │
# └─────┴─────────────────────┴─────────┴─────────────┘
# shape: (9, 5)
# ┌────────────┬───────────────┬─────────────────────┬────────────┬─────────────┐
# │ statistic  ┆ id            ┆ datetime            ┆ user_id    ┆ location_id │
# │ ---        ┆ ---           ┆ ---                 ┆ ---        ┆ ---         │
# │ str        ┆ f64           ┆ str                 ┆ f64        ┆ f64         │
# ╞════════════╪═══════════════╪═════════════════════╪════════════╪═════════════╡
# │ count      ┆ 620017.0      ┆ 620017              ┆ 620017.0   ┆ 620017.0    │
# │ null_count ┆ 0.0           ┆ 0                   ┆ 0.0        ┆ 0.0         │
# │ mean       ┆ 310009.0      ┆ null                ┆ 150.064289 ┆ 9.987275    │
# │ std        ┆ 178983.635264 ┆ null                ┆ 86.885523  ┆ 6.059862    │
# │ min        ┆ 1.0           ┆ 2011-01-01 00:24:04 ┆ 0.0        ┆ 0.0         │
# │ 25%        ┆ 155005.0      ┆ null                ┆ 75.0       ┆ 5.0         │
# │ 50%        ┆ 310009.0      ┆ null                ┆ 150.0      ┆ 10.0        │
# │ 75%        ┆ 465013.0      ┆ null                ┆ 225.0      ┆ 15.0        │
# │ max        ┆ 620017.0      ┆ 2012-12-31 23:51:18 ┆ 300.0      ┆ 20.0        │
# └────────────┴───────────────┴─────────────────────┴────────────┴─────────────┘

# %% [markdown]
# About Direct rentals data

# %%
registered_rentals = pd.read_csv("../data/registered_bike_rentals.csv")

print(registered_rentals.head())
print(registered_rentals.describe())
# Out:
#    id             datetime  user_id  location_id
# 0   1  2011-01-01 00:05:09      158           16
# 1   2  2011-01-01 00:05:21      262           18
# 2   3  2011-01-01 00:05:39       68           18
# 3   4  2011-01-01 00:12:05       12            9
# 4   5  2011-01-01 00:25:58       91           11
#                  id       user_id   location_id
# count  2.672662e+06  2.672662e+06  2.672662e+06
# mean   1.336332e+06  1.500238e+02  9.994752e+00
# std    7.715312e+05  8.690642e+01  6.056529e+00
# min    1.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.681662e+05  7.500000e+01  5.000000e+00
# 50%    1.336332e+06  1.500000e+02  1.000000e+01
# 75%    2.004497e+06  2.250000e+02  1.500000e+01
# max    2.672662e+06  3.000000e+02  2.000000e+01

# %% [markdown]
# About registered rentals data

# %% [markdown]
# Aggregate, group by hours
#
# time series forecasting
#
# weekly patterns
# monthly patterns
# seasonal patterns
# look at distributions per day, per month, per season, compare the same days, months, seasons from 2011 to 2012

# %% [markdown]
# Conclusions

# %% [markdown]
# Check data consistency of weather and holiday

# %% [markdown]
# Conclusions

# %% [markdown]
# Add weather and holiday info to aggregated rental table

# %% [markdown]
# Inspect the same holiday demand distribution

# %% [markdown]
# Does it look consistent that 2011-01-17 "Dr. Martin Luther King, Jr.'s Birthday" has same distribution for 2012-01-16,"Dr. Martin Luther King, Jr.'s Birthday"
#
# or 2011-01-17 and 2012-01-17 have same distribution. same for 2012-01-16 and 2011-01-16
#
# do it for every holiday

# %% [markdown]
# do a heatmap for all columns of the merged table

# %% [markdown]
# Conclusions

# %% [markdown]
# Finally decide on adding new features if relevant
